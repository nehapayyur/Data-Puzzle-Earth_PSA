# %% [markdown]
# <a href="https://colab.research.google.com/github/nehapayyur/Data-Puzzles_Exercises/blob/main/Data_Puzzles_Speed_limit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro
#
# The dataset loaded below represents a random sample of cars speed on certain roads.
#
# Can you figure out what the speed limit is for each road?
# Write back the sum of all roads speeds limits back on the data-puzzles webpage!

# %% [markdown]
# # Kickstart

# %%
import pandas as pd

speeds_df = pd.read_csv('https://raw.githubusercontent.com/hyperc54/data-puzzles-assets/master/visualisation/speeds_data.csv')

# %%
speeds_df.head()
# Out:
#       plate road  speed
# 0  DN9166SU  R87   49.7
# 1  CG4862ZS  R87   49.4
# 2  DV4956AM  R87   49.9
# 3  TL4125OA  R87   51.3
# 4  LX3827BI  R87   48.1

# %%
# Your turn now! figure out the speed limit per road and add them up!
speeds_df_grouped = speeds_df.groupby('road')['speed'].mean()
speeds_df_grouped.head(5)
# Out:
# road
# R17     86.605333
# R48     67.118778
# R77    122.422083
# R80     28.766455
# R87     47.857176
# Name: speed, dtype: float64

# %%
sns.violinplot(speeds_df, x = 'speed', y = 'road', inner = 'box')
# Out:
# <Axes: xlabel='speed', ylabel='road'>

# %%
import numpy as np
def pct_95(x):
  return np.percentile(x, q = 95)

def pct_90(x):
  return np.percentile(x, q = 90)

speeds_df.groupby('road')['speed'].agg([np.mean, pct_90, pct_95])
# Out:
#             mean  pct_90   pct_95
# road
# R17    86.605333    90.3   91.205
# R48    67.118778    69.7   70.000
# R77   122.422083   129.2  130.400
# R80    28.766455    30.1   31.500
# R87    47.857176    50.0   50.500
# R90    96.589000    99.9  101.305
